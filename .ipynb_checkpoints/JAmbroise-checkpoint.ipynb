# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
acquisition4  = pd.read_csv('results/mouvement_exterieur_4/mouvement_exterieur_4_gnss.csv')
acquisition5  = pd.read_csv('results/mouvement_exterieur_5/mouvement_exterieur_5_gnss.csv')
acquisition6  = pd.read_csv('results/mouvement_exterieur_6/mouvement_exterieur_6_gnss.csv')
acquisition7  = pd.read_csv('results/mouvement_exterieur_7/mouvement_exterieur_7_gnss.csv')
acquisition8  = pd.read_csv('results/mouvement_exterieur_8/mouvement_exterieur_8_gnss.csv')
acquisition9  = pd.read_csv('results/mouvement_exterieur_9/mouvement_exterieur_9_gnss.csv')
acquisition10 = pd.read_csv('results/mouvement_exterieur_10/mouvement_exterieur_10_gnss.csv')
acquisition11 = pd.read_csv('results/mouvement_exterieur_11/mouvement_exterieur_11_gnss.csv')
acquisition12 = pd.read_csv('results/mouvement_exterieur_12/mouvement_exterieur_12_gnss.csv')
acquisition13 = pd.read_csv('results/mouvement_exterieur_13/mouvement_exterieur_13_gnss.csv')
acquisition14 = pd.read_csv('results/mouvement_exterieur_14/mouvement_exterieur_14_gnss.csv')
#acquisition15 = pd.read_csv('results/mouvement_exterieur_15/mouvement_exterieur_15_gnss.csv')
#acquisition16 = pd.read_csv('results/mouvement_exterieur_16/mouvement_exterieur_16_gnss.csv')
#acquisition17 = pd.read_csv('results/mouvement_exterieur_17/mouvement_exterieur_17_gnss.csv')
#acquisition18 = pd.read_csv('results/mouvement_exterieur_18/mouvement_exterieur_18_gnss.csv')

# %%
np.array(acquisition1['Latitude'])
# Out:
# array([49.3843195 , 49.38432433, 49.38432867, 49.3843335 , 49.38433783,
#        49.38433783, 49.38435317, 49.3843625 , 49.3843695 , 49.384384  ,
#        49.384397  , 49.384412  , 49.3844255 , 49.384444  , 49.38446333,
#        49.38448067, 49.38449433, 49.384513  , 49.38453333, 49.38454783,
#        49.38457533, 49.3846    , 49.38461967, 49.38464   , 49.38465933,
#        49.384678  , 49.38470033, 49.38472183, 49.3847415 , 49.38476033,
#        49.38478717, 49.3848075 , 49.38482917, 49.38484817, 49.38487467,
#        49.38490067, 49.38493017, 49.38495267, 49.38498267, 49.38501033,
#        49.385044  , 49.38508233, 49.38511833, 49.38515133, 49.38518317,
#        49.38521017, 49.38523483, 49.38525833, 49.38528233, 51.51864133,
#        49.385335  , 49.38536   , 49.38537817, 49.38539317, 49.38539317,
#        49.38540683, 49.38542083, 49.38543333, 49.3854455 , 49.38545983,
#        49.38547367, 49.38548483, 49.38549533, 49.385507  , 49.385518  ,
# ...

# %%
from scipy.stats import levene

A = acquisition4['Latitude'] 
B = acquisition5['Latitude']
C = acquisition6['Latitude']
D = acquisition7['Latitude']

stat, p_value = levene(A, B, C, D)

print(f"Statistique de test : {stat}")
print(f"P-value : {p_value}")
# Out:
# Statistique de test : 2.783763681828136
# P-value : 0.03993981696040434
